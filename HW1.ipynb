# %%
import numpy as np

# %%
n = 100

# %%
def sample_posterior(alpha_post, beta_post, num_samples):
    
    samples = np.random.beta(alpha_post, beta_post, num_samples)
    
    return samples

# %%
def simulate_and_update(alpha, beta, true_p, n=100):
    
    x = np.random.binomial(n, true_p)
    alpha_post = alpha + x
    beta_post = beta + (n - x)
    
    return alpha_post, beta_post, x, n

# %%
true_ps = {'Red': 0.4, 'Blue': 0.5, 'Other': 0.6}

alpha_prior, beta_prior = 1, 1

# %%
posterior_samples = {}

for option, true_p in true_ps.items():
    alpha_post, beta_post, x, n = simulate_and_update(alpha_prior, beta_prior, true_p)
    posterior_samples[option] = sample_posterior(alpha_post, beta_post, n)
    
posterior_samples
# Out:
# {'Red': array([0.3128153 , 0.29876075, 0.3916949 , 0.28803612, 0.3888843 ,
#         0.3560869 , 0.37369641, 0.40023782, 0.42777843, 0.30433873,
#         0.34936291, 0.33749299, 0.36912179, 0.38896766, 0.39544203,
#         0.37997504, 0.38371499, 0.38118758, 0.2810131 , 0.40291658,
#         0.38387961, 0.42076764, 0.31559085, 0.31463963, 0.39527667,
#         0.40333855, 0.41429999, 0.37817071, 0.3572941 , 0.48353165,
#         0.44676175, 0.35107047, 0.45382977, 0.40710066, 0.40211788,
#         0.34823902, 0.42437957, 0.30839573, 0.30311158, 0.31741032,
#         0.38432769, 0.42801581, 0.32277986, 0.36651702, 0.33326212,
#         0.30866584, 0.30471717, 0.39858458, 0.38745036, 0.40567684,
#         0.42002031, 0.37587579, 0.39304502, 0.40213225, 0.47911228,
#         0.45021466, 0.38533655, 0.33260603, 0.31061329, 0.34749197,
#         0.38060492, 0.35552543, 0.42942005, 0.44509993, 0.40825372,
#         0.37907622, 0.41600831, 0.30021318, 0.41898992, 0.33245981,
#         0.40014466, 0.39548977, 0.37730326, 0.40086931, 0.35023822,
#         0.31502289, 0.4409401 , 0.32164665, 0.36855193, 0.36066566,
#         0.35879403, 0.46703494, 0.3683729 , 0.43338676, 0.3403924 ,
#         0.38279681, 0.42374982, 0.32741715, 0.37139271, 0.39193253,
#         0.40001674, 0.2871714 , 0.41971596, 0.40051587, 0.33379941,
#         0.36536319, 0.35868113, 0.3010055 , 0.41284896, 0.40144827]),
#  'Blue': array([0.56214312, 0.55308285, 0.59261806, 0.41432747, 0.59445561,
#         0.5334737 , 0.49341956, 0.53094001, 0.51667153, 0.56056941,
#         0.58951855, 0.49424679, 0.67772333, 0.53150202, 0.58892497,
#         0.54067324, 0.49856506, 0.51665137, 0.52235306, 0.54045866,
#         0.50025161, 0.56278585, 0.53814752, 0.50666865, 0.59586518,
#         0.58625834, 0.54776396, 0.63457386, 0.54880317, 0.56448685,
#         0.66001699, 0.54588062, 0.48544737, 0.54756111, 0.65098644,
#         0.48537497, 0.50591543, 0.54841302, 0.56327883, 0.59488492,
#         0.53934058, 0.58506525, 0.54497863, 0.50584215, 0.55121815,
#         0.58594295, 0.58708158, 0.59372443, 0.51359486, 0.6047698 ,
#         0.54158559, 0.49542897, 0.52871422, 0.46411239, 0.47346883,
#         0.55391091, 0.53615759, 0.57352854, 0.56874938, 0.59274547,
#         0.60429179, 0.5951834 , 0.51465428, 0.58346454, 0.53206369,
#         0.60174335, 0.54513594, 0.55995827, 0.54677747, 0.5401671 ,
#         0.56196009, 0.56341059, 0.52643876, 0.52487335, 0.64416066,
#         0.44153905, 0.54582584, 0.57066688, 0.46733872, 0.50681597,
#         0.54923607, 0.5613872 , 0.54603559, 0.49723949, 0.61963168,
#         0.61411162, 0.61834641, 0.46525828, 0.51493169, 0.62079534,
#         0.59072818, 0.4795896 , 0.5974622 , 0.58431303, 0.55094286,
#         0.594848  , 0.52550254, 0.55594292, 0.4959564 , 0.52486736]),
#  'Other': array([0.60714149, 0.61598294, 0.6129319 , 0.53250015, 0.64581535,
#         0.67230696, 0.58061771, 0.55870636, 0.56939228, 0.50386353,
#         0.61965702, 0.656661  , 0.62401072, 0.64236115, 0.52433184,
#         0.56326799, 0.59231152, 0.60656029, 0.64991112, 0.62317833,
#         0.61243789, 0.64823438, 0.59343446, 0.68136711, 0.65239121,
#         0.61415222, 0.59135575, 0.59006858, 0.64869552, 0.61611698,
#         0.5884194 , 0.62162955, 0.65681669, 0.62781241, 0.62096899,
#         0.54685801, 0.60719234, 0.59286738, 0.51647732, 0.60824931,
#         0.64532059, 0.66298754, 0.55652807, 0.66912948, 0.72126878,
#         0.70500807, 0.55105927, 0.54907474, 0.57666238, 0.5482695 ,
#         0.65303912, 0.64716231, 0.61815278, 0.5437475 , 0.61331281,
#         0.61208575, 0.55539156, 0.63390878, 0.62451323, 0.62670903,
#         0.6421327 , 0.5067005 , 0.57635053, 0.62690838, 0.61070688,
#         0.58517859, 0.5822034 , 0.57950632, 0.59255958, 0.58581562,
#         0.60728464, 0.59033814, 0.65063441, 0.58252707, 0.62720846,
#         0.61581254, 0.51757291, 0.58444981, 0.57024876, 0.67770711,
#         0.58859468, 0.63037622, 0.60159482, 0.60281537, 0.53728113,
#         0.63437535, 0.62530016, 0.69126334, 0.59142677, 0.60066754,
#         0.7243154 , 0.64932235, 0.58356585, 0.62254828, 0.56789786,
#         0.53046279, 0.69096321, 0.62777115, 0.64823747, 0.59676377])}

# %%
options_best_count = {option: 0 for option in true_ps}

for i in range(n):
    theta_samples = {option: posterior_samples[option][i] for option in true_ps}
    best_option = max(theta_samples, key=theta_samples.get)
    options_best_count[best_option] += 1

# %%
probabilities_best_option = {option: count / n for option, count in options_best_count.items()}

probabilities_best_option
# Out:
# {'Red': 0.0, 'Blue': 0.18, 'Other': 0.82}

# %% [markdown]
# The data should be the count of successes, and the update for the posteriors after the simulation are presented in 'posterior samples'.
#
# Based on the result we got as shown above, the "Other" one might be the best option to choose, as it has the largest probabilities.
